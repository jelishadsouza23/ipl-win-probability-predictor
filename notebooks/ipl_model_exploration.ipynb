# %% [markdown]
# # IPL Win Probability Predictor - Model Exploration & Evaluation
# This notebook demonstrates dataset loading, feature engineering, model training with GroupKFold cross validation, probability calibration curves, and feature importances.

# %%
import sys
import os
sys.path.append('..')

from src.data_prep import load_and_preprocess_data
from src.feature_engineering import prepare_feature_matrix
from src.train import train_and_evaluate_models

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Load and Inspect Dataset

# %%
df = load_and_preprocess_data()
print("Dataset Shape:", df.shape)
df.head()

# %% [markdown]
# ## 2. Feature Engineering & Matrix Preparation

# %%
X, y, groups, categorical_cols, numerical_cols = prepare_feature_matrix(df)
print("Feature Columns:", list(X.columns))
print("Target Win Distribution:", np.bincount(y))

# %% [markdown]
# ## 3. Train Models & Calibrate Probabilities

# %%
pipeline, results_df = train_and_evaluate_models()
results_df
